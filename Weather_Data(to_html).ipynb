# %%
import pandas as pd

# %%
csv_file_final = pd.read_csv('WeatherPy-hw.csv')

# %%
df = pd.DataFrame(csv_file)
df.head()
# Out:
#    Unnamed: 0                    City  Cloudiness Country        Date  \
# 0           0                  Hobart          20      AU  1586215753
# 1           1          Saint-Philippe           4      RE  1586215923
# 2           2  Saint-Médard-en-Jalles         100      FR  1586216096
# 3           3              Butaritari         100      KI  1586215900
# 4           4                 Rikitea          80      PF  1586215814
#
#    Humidity    Lat     Lng  Max Temp  Wind Speed
# 0        66 -42.88  147.33     59.00       13.87
# 1        68 -21.36   55.77     75.20        6.93
# 2        87  44.90   -0.72     57.20        2.24
# 3        70   3.07  172.79     82.85        2.46
# 4        65 -23.12 -134.97     76.30        7.23

# %%
df_new = df.rename(columns = {"Unnamed: 0": "City_ID"})

# %%
df_new
# Out:
#      City_ID                    City  Cloudiness Country        Date  \
# 0          0                  Hobart          20      AU  1586215753
# 1          1          Saint-Philippe           4      RE  1586215923
# 2          2  Saint-Médard-en-Jalles         100      FR  1586216096
# 3          3              Butaritari         100      KI  1586215900
# 4          4                 Rikitea          80      PF  1586215814
# ..       ...                     ...         ...     ...         ...
# 586      586                  Develi          75      TR  1586216228
# 587      587               Pran Buri          20      TH  1586216229
# 588      588                 Birjand          55      IR  1586216229
# 589      589    Novochernorechenskiy          80      RU  1586216229
# 590      590             Stokmarknes         100      NO  1586216229
#
#      Humidity    Lat     Lng  Max Temp  Wind Speed
# 0          66 -42.88  147.33     59.00       13.87
# ...

# %%
df_new_html = df_new.to_html()
print(df_new_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Hobart</td>
#       <td>20</td>
#       <td>AU</td>
#       <td>1586215753</td>
#       <td>66</td>
#       <td>-42.88</td>
#       <td>147.33</td>
#       <td>59.00</td>
#       <td>13.87</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Saint-Philippe</td>
#       <td>4</td>
#       <td>RE</td>
#       <td>1586215923</td>
#       <td>68</td>
#       <td>-21.36</td>
#       <td>55.77</td>
#       <td>75.20</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
